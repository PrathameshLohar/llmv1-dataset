# %%
pip install transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 16.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 28.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 44.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 41.6 MB/s eta 0:00:00
# ...

# %%
from transformers import pipeline

# %%
summarizer = pipeline("summarization")
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# ...

# %%
ARTICLE = """"

"""

# %%
output= summarizer(ARTICLE, max_length= 100, min_length=50, do_sample=False, truncation= True)

# %%
output[0]['summary_text']
# Out:
# " Applereleased the developer tools for visionOS just yesterday and I thought we wouldtake a look together at what this thingis really capable of and what the UI isgoing to look like . I installed anumber of the sample applications sothat we can get a feel for what's reallypossible with vision OS and thesorts of applications that apple isimagining that we might develop ."
